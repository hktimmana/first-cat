# %% [markdown]
# <a href="https://colab.research.google.com/github/hktimmana/first-cat/blob/master/vgg_bc_03072020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
#All Necessary Imports
import numpy as np
import os
import time
from keras.applications.vgg16 import VGG16,preprocess_input
from keras.applications.resnet50 import ResNet50,preprocess_input
from keras.preprocessing import image
from keras.layers import Dense, Activation, Flatten,AveragePooling2D,Dense, Dropout, Reshape
from keras.layers import merge, Input
from keras.models import Model
from keras.utils import np_utils
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import tensorflow as tf
from keras import backend as K
from keras.models import Model
import keras
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import glob
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img

from sklearn.utils.class_weight import compute_class_weight
from sklearn.utils.class_weight import compute_sample_weight
from sklearn.model_selection import train_test_split
import sklearn,itertools
from sklearn.metrics import cohen_kappa_score,accuracy_score,f1_score,precision_score,recall_score,roc_auc_score,hinge_loss,roc_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_fscore_support
from sklearn.preprocessing import LabelEncoder
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
#train_path='/content/gdrive/My Drive/research/final/40X/train/**/*.png'
#validation_path='/content/gdrive/My Drive/research/final/40X/val/**/*.png'
#test_path='/content/gdrive/My Drive/research/final/40X/test/**/*.png'
# Out:
# 100X  200X  400X  40X

# %%
cancer_list=['A','DC','F','LC','MC','PC','PT','TA']
IMG_DIM = (224, 224)
train_path='/content/gdrive/My Drive/research/format/40X/train/**/*.png'
validation_path='/content/gdrive/My Drive/research/format/40X/val/**/*.png'
test_path='/content/gdrive/My Drive/research/format/40X/test/**/*.png'
model_path='/content/gdrive/My Drive/research/model/'

train_files = glob.glob(train_path)
train_imgs = np.array([img_to_array(load_img(img, target_size=IMG_DIM)) for img in train_files])
train_labels = [fn.split('/')[-2].strip() for fn in train_files]
#train_idx = [fn.split('/')[-1].split('-')[0].split('_')[-2] for fn in train_files]
validation_files = glob.glob(validation_path)
validation_imgs = np.array([img_to_array(load_img(img, target_size=IMG_DIM)) for img in validation_files])
validation_labels = [fn.split('/')[-2].strip() for fn in validation_files]
#validation_idx = [fn.split('/')[-1].split('-')[0].split('_')[-2] for fn in validation_files]
test_files = glob.glob(test_path)
test_imgs = np.array([img_to_array(load_img(img, target_size=IMG_DIM)) for img in test_files])
test_labels = [fn.split('/')[-2].strip() for fn in test_files]
#test_idx = [fn.split('/')[-1].split('-')[0].split('_')[-2] for fn in test_files]

# %%
train_imgs_scaled = train_imgs.astype('float32')/255
validation_imgs_scaled = validation_imgs.astype('float32')/255

# %%
batch_size = 30
num_classes = 2
epochs = 30
input_shape = (224, 224, 3)

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(train_labels)
# encode wine type labels
train_labels_enc = le.transform(train_labels)
validation_labels_enc = le.transform(validation_labels)

print(train_labels[0:5], train_labels_enc[0:5])
# Out:
# ['M', 'M', 'M', 'M', 'M'] [1 1 1 1 1]

# %%
resolver = tf.distribute.cluster_resolver.TPUClusterResolver()
tf.config.experimental_connect_to_cluster(resolver)
tf.tpu.experimental.initialize_tpu_system(resolver)
strategy = tf.distribute.experimental.TPUStrategy(tf.distribute.cluster_resolver.TPUClusterResolver())
# Out:
# INFO:tensorflow:Initializing the TPU system: grpc://10.40.103.34:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.40.103.34:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# ...

# %%
from keras.applications import vgg16
from keras.models import Model
import keras

vgg = vgg16.VGG16(include_top=False, weights='imagenet', 
                                     input_shape=input_shape)

output = vgg.layers[-1].output
output = keras.layers.Flatten()(output)

vgg_model = Model(vgg.input, output)
vgg_model.trainable = False

for layer in vgg_model.layers:
    layer.trainable = False

vgg_model.summary()
# Out:
# ...
# 58892288/58889256 [==============================] - 1s 0us/step
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# ...

# %%
import pandas as pd
pd.set_option('max_colwidth', -1)

layers = [(layer, layer.name, layer.trainable) for layer in vgg_model.layers]
pd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Layer Trainable'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#                                                         Layer Type  ... Layer Trainable
# 0   <keras.engine.input_layer.InputLayer object at 0x7f793d697fd0>  ...  False
# 1   <keras.layers.convolutional.Conv2D object at 0x7f793d697550>    ...  False
# 2   <keras.layers.convolutional.Conv2D object at 0x7f793d697c18>    ...  False
# 3   <keras.layers.pooling.MaxPooling2D object at 0x7f790b5c0908>    ...  False
# 4   <keras.layers.convolutional.Conv2D object at 0x7f790b5c0c88>    ...  False
# 5   <keras.layers.convolutional.Conv2D object at 0x7f790b5d8940>    ...  False
# 6   <keras.layers.pooling.MaxPooling2D object at 0x7f793f0821d0>    ...  False
# 7   <keras.layers.convolutional.Conv2D object at 0x7f793f082278>    ...  False
# ...

# %%
print("Trainable layers:", vgg_model.trainable_weights)
# Out:
# Trainable layers: []

# %%
bottleneck_feature_example = vgg.predict(train_imgs_scaled[0:1])
print(bottleneck_feature_example.shape)
plt.imshow(bottleneck_feature_example[0][:,:,0])
# Out:
# (1, 7, 7, 512)

# %%
def get_bottleneck_features(model, input_imgs):
    
    features = model.predict(input_imgs, verbose=0)
    return features

# %%
train_features_vgg = get_bottleneck_features(vgg_model, train_imgs_scaled)
validation_features_vgg = get_bottleneck_features(vgg_model, validation_imgs_scaled)

print('Train Bottleneck Features:', train_features_vgg.shape, 
      '\tValidation Bottleneck Features:', validation_features_vgg.shape)
# Out:
# Train Bottleneck Features: (1393, 25088) 	Validation Bottleneck Features: (395, 25088)

# %%
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, InputLayer
from keras.models import Sequential
from keras import optimizers

input_shape = vgg_model.output_shape[1]
with strategy.scope():  
  model = Sequential()
  model.add(InputLayer(input_shape=(input_shape,)))
  model.add(Dense(512, activation='relu', input_dim=input_shape))
  model.add(Dropout(0.3))
  model.add(Dense(512, activation='relu'))
  model.add(Dropout(0.3))
  model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer=optimizers.RMSprop(lr=1e-4),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 512)               12845568
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 513
# ...
# Total params: 13,108,737
# Trainable params: 13,108,737
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x=train_features_vgg, y=train_labels_enc,
                    validation_data=(validation_features_vgg, validation_labels_enc),
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1)
# Out:
# Train on 1393 samples, validate on 395 samples
# Epoch 1/30
# 1393/1393 [==============================] - 6s 5ms/step - loss: 0.6935 - accuracy: 0.6547 - val_loss: 0.5973 - val_accuracy: 0.7342
# Epoch 2/30
# 1393/1393 [==============================] - 6s 4ms/step - loss: 0.5424 - accuracy: 0.7229 - val_loss: 0.4256 - val_accuracy: 0.8203
# Epoch 3/30
# 1393/1393 [==============================] - 6s 4ms/step - loss: 0.4892 - accuracy: 0.7724 - val_loss: 0.3700 - val_accuracy: 0.8658
# Epoch 4/30
# 1393/1393 [==============================] - 6s 4ms/step - loss: 0.4193 - accuracy: 0.8105 - val_loss: 0.4236 - val_accuracy: 0.8329
# Epoch 5/30
# 1393/1393 [==============================] - 6s 4ms/step - loss: 0.3770 - accuracy: 0.8263 - val_loss: 0.3141 - val_accuracy: 0.8861
# Epoch 6/30
# 1393/1393 [==============================] - 6s 4ms/step - loss: 0.3384 - accuracy: 0.8593 - val_loss: 0.4172 - val_accuracy: 0.8051
# Epoch 7/30
# ...

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('Pre-trained CNN (Transfer Learning) Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(1,31))
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, 31, 5))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, 31, 5))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %%
model.save(model_path+'/cats_dogs_tlearn_basic_cnn.h5')
model.save_weights(model_path+'/cats_dogs_tlearn_basic_cnn_w.h5')

# %%
train_datagen = ImageDataGenerator(rescale=1./255, zoom_range=0.3, rotation_range=50,
                                   width_shift_range=0.2, height_shift_range=0.2, shear_range=0.2, 
                                   horizontal_flip=True, fill_mode='nearest')

val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow(train_imgs, train_labels_enc, batch_size=30)
val_generator = val_datagen.flow(validation_imgs, validation_labels_enc, batch_size=20)

# %%
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, InputLayer
from keras.models import Sequential
from keras import optimizers

model = Sequential()
model.add(vgg_model)
model.add(Dense(512, activation='relu', input_dim=input_shape))
model.add(Dropout(0.3))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer=optimizers.RMSprop(lr=2e-5),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# model_1 (Model)              (None, 25088)             14714688
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               12845568
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 513
# ...
# Total params: 27,823,425
# Trainable params: 13,108,737
# Non-trainable params: 14,714,688
# ...

# %%
history = model.fit_generator(train_generator, epochs=30,
                              validation_data=val_generator, verbose=1)
# Out:
# Epoch 1/30
# 47/47 [==============================] - 30s 632ms/step - loss: 0.4415 - accuracy: 0.7861 - val_loss: 0.4211 - val_accuracy: 0.8329
# Epoch 2/30
# 47/47 [==============================] - 29s 620ms/step - loss: 0.4374 - accuracy: 0.8011 - val_loss: 0.5487 - val_accuracy: 0.8203
# Epoch 3/30
# 47/47 [==============================] - 29s 621ms/step - loss: 0.4311 - accuracy: 0.8198 - val_loss: 0.3138 - val_accuracy: 0.8734
# Epoch 4/30
# 47/47 [==============================] - 29s 619ms/step - loss: 0.4121 - accuracy: 0.8234 - val_loss: 0.3933 - val_accuracy: 0.8177
# Epoch 5/30
# 47/47 [==============================] - 29s 620ms/step - loss: 0.4098 - accuracy: 0.8241 - val_loss: 0.2468 - val_accuracy: 0.8886
# Epoch 6/30
# 47/47 [==============================] - 29s 614ms/step - loss: 0.3988 - accuracy: 0.8256 - val_loss: 0.2332 - val_accuracy: 0.8127
# Epoch 7/30
# ...

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('Pre-trained CNN (Transfer Learning) with Image Augmentation Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(1,31))
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, 31, 10))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, 31, 10))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %%
model.save(model_path+'/cats_dogs_tlearn_img_aug_cnn.h5')

# %%
vgg_model.trainable = True

set_trainable = False
for layer in vgg_model.layers:
    if layer.name in ['block5_conv1', 'block4_conv1']:
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False
        
print("Trainable layers:", vgg_model.trainable_weights)
# Out:
# Trainable layers: [<tf.Variable 'block4_conv1/kernel:0' shape=(3, 3, 256, 512) dtype=float32, numpy=
# array([[[[-1.24538150e-02,  8.40655994e-03, -5.28845051e-03, ...,
#           -2.04581907e-03, -3.92359449e-03,  1.30683812e-03],
#          [ 1.15566896e-02,  2.46055960e-03, -4.09082584e-02, ...,
#           -4.92062652e-03, -1.63423386e-03,  8.94230697e-03],
#          [-1.43469922e-04, -5.65873180e-03,  1.84066985e-02, ...,
#           -2.08840682e-03,  2.63321817e-06, -2.50728261e-02],
#          ...,
#          [ 1.37888230e-02, -6.58180192e-03,  9.65370331e-03, ...,
#            7.17610447e-03,  3.45725450e-03,  5.33173978e-03],
#          [ 2.65833316e-03,  7.77704641e-04,  2.86239345e-04, ...,
#           -5.40583069e-03,  8.93119723e-03,  1.40043022e-02],
#          [-8.53933115e-03,  1.43394794e-03, -2.91879033e-03, ...,
#            3.77660524e-03,  2.05454584e-02, -1.35868033e-02]],
#
#         [[-1.20176468e-02,  1.51250837e-03,  3.43130133e-03, ...,
# ...

# %%
layers = [(layer, layer.name, layer.trainable) for layer in vgg_model.layers]
pd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Layer Trainable'])
# Out:
#                                                         Layer Type  ... Layer Trainable
# 0   <keras.engine.input_layer.InputLayer object at 0x7f793d697fd0>  ...  False
# 1   <keras.layers.convolutional.Conv2D object at 0x7f793d697550>    ...  False
# 2   <keras.layers.convolutional.Conv2D object at 0x7f793d697c18>    ...  False
# 3   <keras.layers.pooling.MaxPooling2D object at 0x7f790b5c0908>    ...  False
# 4   <keras.layers.convolutional.Conv2D object at 0x7f790b5c0c88>    ...  False
# 5   <keras.layers.convolutional.Conv2D object at 0x7f790b5d8940>    ...  False
# 6   <keras.layers.pooling.MaxPooling2D object at 0x7f793f0821d0>    ...  False
# 7   <keras.layers.convolutional.Conv2D object at 0x7f793f082278>    ...  False
# 8   <keras.layers.convolutional.Conv2D object at 0x7f790b5c9828>    ...  False
# 9   <keras.layers.convolutional.Conv2D object at 0x7f790ada48d0>    ...  False
# 10  <keras.layers.pooling.MaxPooling2D object at 0x7f790adaa358>    ...  False
# ...

# %%
train_datagen = ImageDataGenerator(rescale=1./255, zoom_range=0.3, rotation_range=50,
                                   width_shift_range=0.2, height_shift_range=0.2, shear_range=0.2, 
                                   horizontal_flip=True, fill_mode='nearest')

val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow(train_imgs, train_labels_enc, batch_size=30)
val_generator = val_datagen.flow(validation_imgs, validation_labels_enc, batch_size=20)

# %%
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, InputLayer
from keras.models import Sequential
from keras import optimizers
with strategy.scope():  
  model = Sequential()
  model.add(vgg_model)
  model.add(Dense(512, activation='relu', input_dim=input_shape))
  model.add(Dropout(0.3))
  model.add(Dense(512, activation='relu'))
  model.add(Dropout(0.3))
  model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer=optimizers.RMSprop(lr=1e-5),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# model_1 (Model)              (None, 25088)             14714688
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               12845568
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 513
# ...
# Total params: 27,823,425
# Trainable params: 26,087,937
# Non-trainable params: 1,735,488
# ...

# %%
history = model.fit_generator(train_generator,  epochs=30,
                              validation_data=val_generator,  verbose=1)
# Out:
# Epoch 1/30
# 47/47 [==============================] - 55s 1s/step - loss: 0.6245 - accuracy: 0.6719 - val_loss: 0.5113 - val_accuracy: 0.6810
# Epoch 2/30
# 47/47 [==============================] - 59s 1s/step - loss: 0.5330 - accuracy: 0.7416 - val_loss: 0.3489 - val_accuracy: 0.8835
# Epoch 3/30
# 47/47 [==============================] - 59s 1s/step - loss: 0.4131 - accuracy: 0.8191 - val_loss: 0.0896 - val_accuracy: 0.9190
# Epoch 4/30
# 47/47 [==============================] - 59s 1s/step - loss: 0.3741 - accuracy: 0.8464 - val_loss: 0.1599 - val_accuracy: 0.9266
# Epoch 5/30
# 47/47 [==============================] - 59s 1s/step - loss: 0.3305 - accuracy: 0.8557 - val_loss: 0.4526 - val_accuracy: 0.9291
# Epoch 6/30
# 47/47 [==============================] - 59s 1s/step - loss: 0.3117 - accuracy: 0.8686 - val_loss: 0.0961 - val_accuracy: 0.9190
# Epoch 7/30
# ...

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('Pre-trained CNN (Transfer Learning) with Fine-Tuning & Image Augmentation Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(1,31))
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, 31, 10))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, 31, 10))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %%
model.save(model_path+'/cats_dogs_tlearn_finetune_img_aug_cnn.h5')
